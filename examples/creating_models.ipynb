# %%
import sys
sys.path.append("../")

# %%
from ideal_rcf.models.config import ModelConfig, MixerConfig
from ideal_rcf.models.framework import FrameWork

# %% [markdown]
# ### Models Parameters

# %%
layers_tbnn = 3
units_tbnn = 150
features_input_shape = (15,3)
tensor_features_input_shape = (20,3,3)

layers_evnn = 2
units_evnn = 150
tensor_features_linear_input_shape = (3,)

layers_oevnn = 2
units_oevnn = 150
tensor_features_linear_oev_input_shape = (3,)

learning_rate=5e-4
learning_rate_oevnn=1e-4

tbnn_mixer_config = MixerConfig(
    features_mlp_layers=5,
    features_mlp_units=150
)

evnn_mixer_config = MixerConfig(
    features_mlp_layers=3,
    features_mlp_units=150
)

oevnn_mixer_config = MixerConfig(
    features_mlp_layers=5,
    features_mlp_units=150
)

# %% [markdown]
# ### Example: Create TBNN_model via ModelConfig

# %%
TBNN_config = ModelConfig(
    layers_tbnn=layers_tbnn,
    units_tbnn=units_tbnn,
    features_input_shape=features_input_shape,
    tensor_features_input_shape=tensor_features_input_shape,
    tbnn_mixer_config=tbnn_mixer_config
)
assert TBNN_config._evtbnn == False
assert TBNN_config._oevnltbnn == False
print('Sucess creating mixer TBNN ModelConfig obj')
tbnn = FrameWork(TBNN_config)
tbnn.compile_models()
### acess compiled model
tbnn.models.tbnn.summary()
# Out:
# Sucess creating mixer TBNN ModelConfig obj
# Model: "tbnn_framework"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  features_input_layer (InputLay  [(None, 15, 3)]     0           []
#  er)
#
#  tensor_features_input_layer (I  [(None, 20, 3, 3)]  0           []
#  nputLayer)
#
#  mixer_tbnn (Functional)        (None, 9, 1)         276539      ['features_input_layer[0][0]',
#                                                                   'tensor_features_input_layer[0][
#                                                                  0]']
#
#  lambda_3 (Lambda)              (None, 1)            0           ['mixer_tbnn[0][0]']
#
#  lambda_5 (Lambda)              (None, 1)            0           ['mixer_tbnn[0][0]']
#
#  add_1 (Add)                    (None, 1)            0           ['lambda_3[0][0]',
#                                                                   'lambda_5[0][0]']
#
#  lambda_4 (Lambda)              (None, 1)            0           ['mixer_tbnn[0][0]']
#
#  tf.math.negative_1 (TFOpLambda  (None, 1)           0           ['add_1[0][0]']
#  )
#
#  concatenate_1 (Concatenate)    (None, 4)            0           ['lambda_3[0][0]',
#                                                                   'lambda_4[0][0]',
#                                                                   'lambda_5[0][0]',
#                                                                   'tf.math.negative_1[0][0]']
#
# ==================================================================================================
# Total params: 276,539
# Trainable params: 276,539
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %% [markdown]
# ### Example: Create eVTBNN_model via ModelConfig

# %%
eVTBNN_config = ModelConfig(
    layers_tbnn=layers_tbnn,
    units_tbnn=units_tbnn,
    features_input_shape=15,#features_input_shape,
    tensor_features_input_shape=tensor_features_input_shape,
    layers_evnn=layers_evnn,
    units_evnn=units_evnn,
    tensor_features_linear_input_shape=tensor_features_linear_input_shape,
)

assert eVTBNN_config._evtbnn == True
assert eVTBNN_config._oevnltbnn == False
print('Sucess creating eVTBNN_config ModelConfig obj')
evtbnn = FrameWork(eVTBNN_config)
evtbnn.compile_models()
### acess compiled model
evtbnn.models.evtbnn.summary()
# Out:
# Sucess creating eVTBNN_config ModelConfig obj
# Model: "evtbnn_framework"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  features_input_layer (InputLay  [(None, 15)]        0           []
#  er)
#
#  tensor_features_input_layer (I  [(None, 20, 3, 3)]  0           []
#  nputLayer)
#
#  tensor_features_evnn_input_lay  [(None, 3)]         0           []
#  er (InputLayer)
#
#  tbnn (Functional)              (None, 9, 1)         50720       ['features_input_layer[0][0]',
#                                                                   'tensor_features_input_layer[0][
#                                                                  0]']
#
#  evnn (Functional)              (None, 3, 1)         25201       ['features_input_layer[0][0]',
#                                                                   'tensor_features_evnn_input_laye
#                                                                  r[0][0]']
#
#  lambda_6 (Lambda)              (None, 1)            0           ['tbnn[0][0]']
#
#  lambda_9 (Lambda)              (None, 1)            0           ['evnn[0][0]']
#
#  lambda_8 (Lambda)              (None, 1)            0           ['tbnn[0][0]']
#
#  lambda_11 (Lambda)             (None, 1)            0           ['evnn[0][0]']
#
#  add_2 (Add)                    (None, 1)            0           ['lambda_6[0][0]',
#                                                                   'lambda_9[0][0]']
#
#  add_4 (Add)                    (None, 1)            0           ['lambda_8[0][0]',
#                                                                   'lambda_11[0][0]']
#
#  lambda_7 (Lambda)              (None, 1)            0           ['tbnn[0][0]']
#
#  lambda_10 (Lambda)             (None, 1)            0           ['evnn[0][0]']
#
#  add_5 (Add)                    (None, 1)            0           ['add_2[0][0]',
#                                                                   'add_4[0][0]']
#
#  add_3 (Add)                    (None, 1)            0           ['lambda_7[0][0]',
#                                                                   'lambda_10[0][0]']
#
#  tf.math.negative_2 (TFOpLambda  (None, 1)           0           ['add_5[0][0]']
#  )
#
#  concatenate_2 (Concatenate)    (None, 4)            0           ['add_2[0][0]',
#                                                                   'add_3[0][0]',
#                                                                   'add_4[0][0]',
#                                                                   'tf.math.negative_2[0][0]']
#
# ==================================================================================================
# Total params: 75,921
# Trainable params: 75,921
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %% [markdown]
# ### Example: Create OeVNLTBNN_model via ModelConfig with Mixer architecture

# %%
OeVNLTBNN_config = ModelConfig(
    layers_tbnn=layers_tbnn,
    units_tbnn=units_tbnn,
    features_input_shape=features_input_shape,
    tensor_features_input_shape=tensor_features_input_shape,
    layers_evnn=layers_evnn,
    units_evnn=units_evnn,
    tensor_features_linear_input_shape=tensor_features_linear_input_shape,
    layers_oevnn=layers_oevnn,
    units_oevnn=units_oevnn,
    tensor_features_linear_oev_input_shape=tensor_features_linear_oev_input_shape,
    learning_rate=learning_rate,
    learning_rate_oevnn=learning_rate_oevnn,
    tbnn_mixer_config=tbnn_mixer_config,
    evnn_mixer_config=evnn_mixer_config,
    oevnn_mixer_config=oevnn_mixer_config
)
assert OeVNLTBNN_config._evtbnn == True
assert OeVNLTBNN_config._oevnltbnn == True
print('Sucess creating mixer OeVNLTBNN_config ModelConfig obj')
oevnltbnn = FrameWork(OeVNLTBNN_config)
oevnltbnn.compile_models()
### extract oev model from oevnn so that S_DNS is not required to run inference
oevnltbnn.extract_oev()
### acess compiled model
print(oevnltbnn.models.oevnn.summary())
print(oevnltbnn.models.nltbnn.summary())
# Out:
# Sucess creating mixer OeVNLTBNN_config ModelConfig obj
# Model: "oevnn"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  features_input_layer (InputLay  [(None, 15, 3)]     0           []
#  er)
#
#  layer_normalization_36 (LayerN  (None, 15, 3)       90          ['features_input_layer[0][0]']
#  ormalization)
#
#  tf.compat.v1.transpose_36 (TFO  (None, 3, 15)       0           ['layer_normalization_36[0][0]']
#  pLambda)
#
#  dense_132 (Dense)              (None, 3, 15)        240         ['tf.compat.v1.transpose_36[0][0]
#                                                                  ']
#
#  tf.compat.v1.transpose_37 (TFO  (None, 15, 3)       0           ['dense_132[0][0]']
#  pLambda)
#
#  dropout_54 (Dropout)           (None, 15, 3)        0           ['tf.compat.v1.transpose_37[0][0]
#                                                                  ']
#
#  tf.__operators__.add_36 (TFOpL  (None, 15, 3)       0           ['dropout_54[0][0]',
#  ambda)                                                           'features_input_layer[0][0]']
#
#  layer_normalization_37 (LayerN  (None, 15, 3)       90          ['tf.__operators__.add_36[0][0]']
#  ormalization)
#
#  dense_133 (Dense)              (None, 15, 150)      600         ['layer_normalization_37[0][0]']
#
#  dense_134 (Dense)              (None, 15, 150)      22650       ['dense_133[0][0]']
#
#  dense_135 (Dense)              (None, 15, 150)      22650       ['dense_134[0][0]']
#
#  dense_136 (Dense)              (None, 15, 150)      22650       ['dense_135[0][0]']
#
#  dense_137 (Dense)              (None, 15, 150)      22650       ['dense_136[0][0]']
#
#  dropout_55 (Dropout)           (None, 15, 150)      0           ['dense_137[0][0]']
#
#  dense_138 (Dense)              (None, 15, 3)        453         ['dropout_55[0][0]']
#
#  dropout_56 (Dropout)           (None, 15, 3)        0           ['dense_138[0][0]']
#
#  tf.__operators__.add_37 (TFOpL  (None, 15, 3)       0           ['dropout_56[0][0]',
#  ambda)                                                           'tf.__operators__.add_36[0][0]']
#
#  layer_normalization_38 (LayerN  (None, 15, 3)       90          ['tf.__operators__.add_37[0][0]']
#  ormalization)
#
#  tf.compat.v1.transpose_38 (TFO  (None, 3, 15)       0           ['layer_normalization_38[0][0]']
#  pLambda)
#
#  dense_139 (Dense)              (None, 3, 15)        240         ['tf.compat.v1.transpose_38[0][0]
#                                                                  ']
#
#  tf.compat.v1.transpose_39 (TFO  (None, 15, 3)       0           ['dense_139[0][0]']
#  pLambda)
#
#  dropout_57 (Dropout)           (None, 15, 3)        0           ['tf.compat.v1.transpose_39[0][0]
#                                                                  ']
#
#  tf.__operators__.add_38 (TFOpL  (None, 15, 3)       0           ['dropout_57[0][0]',
#  ambda)                                                           'tf.__operators__.add_37[0][0]']
#
#  layer_normalization_39 (LayerN  (None, 15, 3)       90          ['tf.__operators__.add_38[0][0]']
#  ormalization)
#
#  dense_140 (Dense)              (None, 15, 150)      600         ['layer_normalization_39[0][0]']
#
#  dense_141 (Dense)              (None, 15, 150)      22650       ['dense_140[0][0]']
#
#  dense_142 (Dense)              (None, 15, 150)      22650       ['dense_141[0][0]']
#
#  dense_143 (Dense)              (None, 15, 150)      22650       ['dense_142[0][0]']
#
#  dense_144 (Dense)              (None, 15, 150)      22650       ['dense_143[0][0]']
#
#  dropout_58 (Dropout)           (None, 15, 150)      0           ['dense_144[0][0]']
#
#  dense_145 (Dense)              (None, 15, 3)        453         ['dropout_58[0][0]']
#
#  dropout_59 (Dropout)           (None, 15, 3)        0           ['dense_145[0][0]']
#
#  tf.__operators__.add_39 (TFOpL  (None, 15, 3)       0           ['dropout_59[0][0]',
#  ambda)                                                           'tf.__operators__.add_38[0][0]']
#
#  tf.__operators__.getitem_7 (Sl  (None, 15)          0           ['tf.__operators__.add_39[0][0]']
#  icingOpLambda)
#
#  dense_146 (Dense)              (None, 1)            16          ['tf.__operators__.getitem_7[0][0
#                                                                  ]']
#
# ==================================================================================================
# Total params: 184,162
# Trainable params: 184,162
# Non-trainable params: 0
# __________________________________________________________________________________________________
# None
# Model: "nltbnn_framework"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  features_input_layer (InputLay  [(None, 15, 3)]     0           []
#  er)
#
#  tensor_features_input_layer (I  [(None, 20, 3, 3)]  0           []
#  nputLayer)
#
#  tensor_features_evnn_input_lay  [(None, 3)]         0           []
#  er (InputLayer)
#
#  mixer_tbnn (Functional)        (None, 9, 1)         276539      ['features_input_layer[0][0]',
#                                                                   'tensor_features_input_layer[0][
#                                                                  0]']
#
#  mixer_evnn (Functional)        (None, 3, 1)         93562       ['features_input_layer[0][0]',
#                                                                   'tensor_features_evnn_input_laye
#                                                                  r[0][0]']
#
#  lambda_18 (Lambda)             (None, 1)            0           ['mixer_tbnn[0][0]']
#
#  lambda_21 (Lambda)             (None, 1)            0           ['mixer_evnn[0][0]']
#
#  lambda_20 (Lambda)             (None, 1)            0           ['mixer_tbnn[0][0]']
#
#  lambda_23 (Lambda)             (None, 1)            0           ['mixer_evnn[0][0]']
#
#  add_10 (Add)                   (None, 1)            0           ['lambda_18[0][0]',
#                                                                   'lambda_21[0][0]']
#
#  add_12 (Add)                   (None, 1)            0           ['lambda_20[0][0]',
#                                                                   'lambda_23[0][0]']
#
#  lambda_19 (Lambda)             (None, 1)            0           ['mixer_tbnn[0][0]']
#
#  lambda_22 (Lambda)             (None, 1)            0           ['mixer_evnn[0][0]']
#
#  add_13 (Add)                   (None, 1)            0           ['add_10[0][0]',
#                                                                   'add_12[0][0]']
#
#  add_11 (Add)                   (None, 1)            0           ['lambda_19[0][0]',
#                                                                   'lambda_22[0][0]']
#
#  tf.math.negative_4 (TFOpLambda  (None, 1)           0           ['add_13[0][0]']
#  )
#
#  concatenate_4 (Concatenate)    (None, 4)            0           ['add_10[0][0]',
#                                                                   'add_11[0][0]',
#                                                                   'add_12[0][0]',
#                                                                   'tf.math.negative_4[0][0]']
#
# ==================================================================================================
# Total params: 370,101
# Trainable params: 370,101
# Non-trainable params: 0
# __________________________________________________________________________________________________
# None
